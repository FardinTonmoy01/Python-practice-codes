# %%
import bcrypt

# Password to be hashed
password = "234567"

# Hashing the password
hashed_password = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt())

# Printing the hashed password
print("Hashed Password:", hashed_password.decode('utf-8'))
# Out:
# Collecting bcrypt
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: bcrypt
# Successfully installed bcrypt-4.0.1
# Hashed Password: $2b$12$/oplBTGS7Z/UhirUmKx6r.eDAqJNTCgPZc62PMgRONrYaTJa2ow4W
