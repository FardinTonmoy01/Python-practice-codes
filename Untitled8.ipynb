# %%
from google.colab import drive
drive.mount('/content/gdrive')

data_path = "/content/drive/My Drive/Colab Notebooks/emails.csv"
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from datetime import datetime
from gensim.models import Word2Vec



# Replace "path/to/email.csv" with your actual data path
data_path = "/content/drive/My Drive/Colab Notebooks/emails.csv"

# Define user email and profile (adapt based on your data)
user_email = "fardintonmoy01@gmail.com"
user_profile = ... # Implement your user profile representation

# Load data and handle missing values
df = pd.read_csv(data_path)
df.dropna(inplace=True)

# Choose your text feature extraction technique
# Comment out whichever you don't want to use

# # Bag-of-words
# vectorizer = CountVectorizer(max_features=1000)
# features_bow = vectorizer.fit_transform(df["content"])

# TF-IDF
vectorizer = TfidfVectorizer(max_features=1000)
features_bow = vectorizer.fit_transform(df["content"])

# Create features for closeness

sender_similarity = df["from"].apply(lambda x: cosine_similarity(user_email, x))

# Topic similarity with Word2Vec
model = Word2Vec(df["content"].tolist())
topic_vectors = df["content"].apply(lambda x: model.wv.doc2vec(x))
topic_similarity = topic_vectors.apply(lambda x: cosine_similarity(user_profile, x))

# Create features for timeliness
df["sent_date"] = pd.to_datetime(df["sent_date"])
time_diff = (datetime.now() - df["sent_date"]).dt.total_seconds()

# Create features for conciseness
word_count = df["content"].apply(lambda x: len(x.split()))

# Combine features with pre-processed data
if 'features_bow' in locals():
    features = features_bow
else:
    features = None

features = pd.concat([features, sender_similarity,
                      topic_similarity, time_diff, word_count], axis=1)

df_processed = pd.concat([df, features], axis=1)

# Save the updated pre-processed dataset
df_processed.to_csv("processed_enron_email_dataset_with_features.csv", index=False)

print("Data preprocessed with features and saved!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'content'
#
# The above exception was the direct cause of the following exception:
#
# ...
