# %%
class hill_climbing:

  def __init__():
    list=[2, 1, 5, 0, 8, 4, 10, 0, 20, 10]
    length=len(list)
  
 
  def calc_cost(state):
    count=0
    i=0
    for i in list:
      j=i+1
      for j in list:
        if list[j]<list[i]:
          count= count+1;
    return count


  def state_generation(current_state, current_state_cost):
    i=0
    
    for i in list:
      j=i+1
      for j in list:
        if list[j]<list[i]:
          temp=list[i]
          index=list.index(list[i])
          list.remove(list[i])          
          list.insert(index,list[j])
          index2=list.index(list[j])
          list.remove(list[j]) 
          list.insert(index2,temp)
     
      cost= calc_cost(state)
      cost_list.append(cost)
      cost_list.sort()
      lower_cost=cost_list[0]
      if(lower_cost>cost):
        return list,cost
      else:
        return list,None




  def goal_state(state):
    if calc_cost(state):
      return True
    else:
      return False

  def main(): 
    state=__init__
    while goal_test(state)!=True:
      cost=calc_cost(state)
      list2=state_generation(state,cost)
      cost2=list2[-1]
      list2.remove(list2[-1])
      if cost2==None:
        print(state)
        break
