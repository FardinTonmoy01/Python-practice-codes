# %%
list=[for x range(6)]
list.append([1,2])

print(list)
# Out:
#   File "<ipython-input-5-d1a4613a5699>", line 1
#     list=[for x range(6)]
#             ^
# SyntaxError: invalid syntax

# %%
list[2]="a";
print(list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-4c0ea7f51af5> in <module>()
# ----> 1 list[2]="a";
#       2 print(list)
#
# IndexError: list assignment index out of range
